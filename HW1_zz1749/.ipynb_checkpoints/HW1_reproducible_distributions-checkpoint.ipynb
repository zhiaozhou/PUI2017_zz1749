# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    ReprRandAll[i] = np.random.randn(2,100) + np.random.randn(1)
print (ReprRandAll)
# Out:
# [[[-1.57115382 -2.75063082 -0.304046   ..., -3.55621524 -1.56671895
#    -0.73542386]
#   [-1.25784698 -0.71299114 -2.53926771 ..., -2.88100975 -2.04589384
#    -1.71311212]]
#
#  [[ 1.14274201  1.1091698   1.39527938 ...,  0.83784411  0.15283412
#    -0.04019926]
#   [-1.6013207   1.32978345  0.56531188 ...,  2.35283385  0.87119703
#    -0.20720381]]
#
#  [[-0.4319655  -0.7646651  -0.70765284 ...,  0.34446056 -0.46392499
#    -0.18455157]
#   [-1.96127615 -2.15092656 -0.15562343 ..., -1.5486325  -1.97568968
#    -2.69767556]]
#
#  ...,
#  [[-0.02920023  0.36960586  0.26720461 ...,  0.45808089  2.10953117
#    -1.69157533]
#   [-0.51837622 -1.33409121 -0.20832791 ..., -0.14591534 -0.51095688
#     0.33230481]]
#
#  [[ 0.8103181  -0.41956054 -0.43482183 ..., -2.37189604  0.12979052
#     0.07747946]
#   [ 1.17396189 -0.17333616 -0.03782802 ..., -3.148898    1.25778323
#    -0.28357953]]
#
#  [[-0.06975051  1.84518091 -0.06551896 ..., -3.05981801  0.27676707
#     1.16441921]
#   [-0.24246468  0.57579378 -1.1574451  ...,  1.34472258 -0.69253171
#    -0.69788444]]]

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 
for i in range(50):
    for j in range(100):
        pl.plot(ReprRandAll[i][0][j],ReprRandAll[i][1][j],'o')
plt.xlabel('Samples From Normal Distribution')
plt.ylabel('Samples From Normal Distribution')
plt.title('2-dimensional Random Datapoints in a Gaussian Distribution with randomly different means',fontsize = 11)
pl.show()
# code here
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1:
#
# 2-dimensional Random Datapoints in a Gaussian Distribution

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
NewReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    NewReprRandAll[i][0] = np.random.randn(100) + np.random.randn(1)
    NewReprRandAll[i][1] = np.random.randn(100) + np.random.randn(1)
print (NewReprRandAll)
# Out:
# [[[ -1.40013118e+00  -4.41730615e-01  -1.92080074e+00 ...,  -2.01831621e+00
#     -1.14803569e+00   1.74238434e-01]
#   [ -1.59533082e+00  -6.40129971e-01   1.68334392e-01 ...,   3.71405834e-01
#     -7.99175491e-01  -1.80348850e+00]]
#
#  [[  1.90071343e+00   2.77747059e+00   1.84106266e+00 ...,   2.00384808e+00
#      1.73832572e+00  -4.19950772e-01]
#   [  6.00767213e-01   5.15385937e-01   7.53962056e-01 ...,   1.56020913e+00
#      2.21036940e+00   1.82310167e+00]]
#
#  [[ -3.31077016e-01   5.63377742e-01  -1.23064271e+00 ...,  -4.49981164e-01
#      1.54860435e+00  -2.82528230e-01]
#   [  1.82773600e+00   3.03647747e-01   4.42239586e-01 ...,   3.59434662e-01
#     -8.96177398e-02  -1.12183091e+00]]
#
#  ...,
#  [[ -1.53281626e+00  -1.21477136e+00   5.09488969e-01 ...,  -8.17277739e-01
#     -2.37346456e-01  -1.50697129e+00]
#   [  3.88508149e+00  -4.22226847e-01   3.37144965e-01 ...,  -5.09868870e-01
#      1.54382242e+00   6.61043001e-01]]
#
#  [[ -7.86537405e-01  -1.72261810e+00   3.11832267e-04 ...,  -1.51820530e+00
#      2.19708003e-03  -2.12023584e+00]
#   [ -4.72838982e-01  -1.73336305e+00   3.85369781e-01 ...,  -2.56266210e-02
#     -9.17454196e-01  -3.87743212e-01]]
#
#  [[  9.14435381e-02   1.80415112e+00   3.86131056e-01 ...,   5.51314935e-01
#      5.71368964e-01   1.20523612e+00]
#   [ -1.43954679e+00  -7.39076750e-02  -1.46024612e+00 ...,   7.91184713e-01
#     -4.85885319e-01   1.11437366e+00]]]

# %%
for i in range(50):
    for j in range(100):
        pl.plot(NewReprRandAll[i][0][j],NewReprRandAll[i][1][j],'o')
plt.xlabel('Samples From Normal Distribution')
plt.ylabel('Samples From Normal Distribution')
plt.title('2-dimensional Random Datapoints in a Gaussian Distribution with randomly different means for each distribution',fontsize = 11)
pl.show()# plot here...

# %%
SingleLineReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    #make means linear
    SingleLineReprRandAll[i][0] = np.random.randn(100) + i
    SingleLineReprRandAll[i][1] = np.random.randn(100) + i*2
print (SingleLineReprRandAll)
# Out:
# [[[ -1.13371747e+00  -4.00202692e-01  -3.18891996e-01 ...,  -1.54512060e-01
#      3.08593884e-01   7.59337777e-01]
#   [  6.06554997e-01  -5.36786972e-01  -5.06291525e-01 ...,  -3.23570213e-01
#      3.83079105e-02   2.30851492e-01]]
#
#  [[  3.95524175e-03   1.09326946e+00   1.10481679e+00 ...,   6.64790475e-01
#      9.51164945e-01   1.62748354e+00]
#   [  6.41176077e-01   1.38098007e+00   2.03827701e+00 ...,   1.22310741e+00
#      2.46835833e+00   3.43936485e+00]]
#
#  [[ -5.80306181e-02   2.24175557e+00   1.87121048e+00 ...,   1.92639415e+00
#      3.29432795e+00   2.98676426e+00]
#   [  3.62500473e+00   4.02195092e+00   3.57354030e+00 ...,   3.95060912e+00
#      2.93869753e+00   5.66516797e+00]]
#
#  ...,
#  [[  4.66935653e+01   4.70921173e+01   4.68276727e+01 ...,   4.62219842e+01
#      4.86167298e+01   4.80925157e+01]
#   [  9.47997589e+01   9.23419125e+01   9.36328745e+01 ...,   9.29341742e+01
#      9.48748502e+01   9.32312569e+01]]
#
#  [[  4.72447814e+01   4.67850469e+01   4.91354509e+01 ...,   4.83325542e+01
#      4.53439946e+01   4.80780803e+01]
#   [  9.54187481e+01   9.58705655e+01   9.62331547e+01 ...,   9.50418900e+01
#      9.67905056e+01   9.47651293e+01]]
#
#  [[  4.94671659e+01   4.94668186e+01   4.93785420e+01 ...,   4.90852040e+01
#      4.86061427e+01   4.93231543e+01]
#   [  9.67733076e+01   9.72094515e+01   9.87264938e+01 ...,   9.80120286e+01
#      9.96143784e+01   9.91359167e+01]]]

# %%
for i in range(50):
    for j in range(100):
        pl.plot(SingleLineReprRandAll[i][0][j],SingleLineReprRandAll[i][1][j],'o')
plt.xlabel('Samples From Normal Distribution')
plt.ylabel('Samples From Normal Distribution')
plt.title('2-dimensional Random Datapoints in a Gaussian Distribution with different means in a single line',fontsize = 11)
pl.show()# plot here...
