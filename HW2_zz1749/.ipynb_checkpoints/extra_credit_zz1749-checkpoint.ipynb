# %%
# Author: Zhiao Zhou
# Assignment 3

from __future__ import print_function
import sys
import os
import json
import urllib
import pandas as pd
import numpy as np
from datetime import datetime
# %pylab inline
plt.rc('font', size=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
os.getenv("DFDATA")
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
data = pd.read_csv(os.getenv("DFDATA")+"/724b-yxwa/1476480727/724b-yxwa.csv")

# %%
data.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    29588367  12/28/2014 12:00:00 AM  02/26/2015 12:00:00 AM  DOHMH
# 1    27030873  01/02/2014 12:00:00 AM  03/12/2014 12:00:00 AM  DOHMH
# 2    27030879  01/02/2014 12:00:00 AM  02/20/2014 12:00:00 AM  DOHMH
# 3    27033718  01/02/2014 12:00:00 AM  02/19/2014 02:00:03 PM  DOHMH
# 4    27033813  01/02/2014 12:00:00 AM  01/09/2014 12:00:00 AM  DOHMH
#
#                                Agency Name Complaint Type    Descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#              Location Type  Incident Zip      Incident Address  \
# ...

# %%
data = pd.DataFrame({"Created Date" : list(data.iloc[:,1]),"Incident Zip":list(data.iloc[:,8])})

# %%
data.head()
# Out:
#              Created Date  Incident Zip
# 0  12/28/2014 12:00:00 AM         11233
# 1  01/02/2014 12:00:00 AM         11222
# 2  01/02/2014 12:00:00 AM         11201
# 3  01/02/2014 12:00:00 AM         11217
# 4  01/02/2014 12:00:00 AM         11214

# %%
new_x = []
for i in range(len(list(data["Created Date"]))):
    new_x.append(datetime.datetime.strptime(list(data["Created Date"])[i],'%m/%d/%Y %I:%M:%S %p'))
print(new_x)
# Out:
# [datetime.datetime(2014, 12, 28, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 2, 0, 0), datetime.datetime(2014, 1, 3, 0, 0), datetime.datetime(2014, 1, 4, 0, 0), datetime.datetime(2014, 1, 4, 0, 0), datetime.datetime(2014, 1, 5, 0, 0), datetime.datetime(2014, 1, 4, 0, 0), datetime.datetime(2014, 1, 5, 0, 0), datetime.datetime(2014, 1, 5, 0, 0), datetime.datetime(2014, 1, 5, 0, 0), datetime.datetime(2014, 1, 5, 0, 0), datetime.datetime(2014, 1, 6, 0, 0), datetime.datetime(2014, 1, 7, 0, 0), datetime.datetime(2014, 1, 7, 20, 20, 25), datetime.datetime(2014, 1, 7, 0, 0), datetime.datetime(2014, 1, 7, 0, 0), datetime.datetime(2014, 1, 7, 0, 0), datetime.datetime(2014, 1, 7, 19, 8, 54), datetime.datetime(2014, 1, 8, 0, 0), datetime.datetime(2014
# ...

# %%
data["Created Date"] = new_x

# %%
data.head()
# Out:
#   Created Date  Incident Zip
# 0   2014-12-28         11233
# 1   2014-01-02         11222
# 2   2014-01-02         11201
# 3   2014-01-02         11217
# 4   2014-01-02         11214

# %%
data.plot(data["Created Date"],["Incident Zip"],rot=90,ylim=[11200,11250])

plt.xlabel('Created Date')
plt.ylabel('Incident Zip')
plt.title('Reducted Dataframe')
plt.legend(loc="upper right")
plt.show()
